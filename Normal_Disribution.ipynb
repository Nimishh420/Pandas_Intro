# %% [markdown]
# <a href="https://colab.research.google.com/github/Nimishh420/Pandas_Intro/blob/main/Normal_Disribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8c06acf3-2b0b-4e8f-b8eb-81c7129dd082" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c06acf3-2b0b-4e8f-b8eb-81c7129dd082">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
beml_df = pd.read_csv("BEML.csv")
beml_df
# Out:
#             Date     Open     High      Low     Last    Close  \
# 0     2010-01-04  1121.00  1151.00  1121.00  1134.00  1135.60
# 1     2010-01-05  1146.80  1149.00  1128.75  1135.00  1134.60
# 2     2010-01-06  1140.00  1164.25  1130.05  1137.00  1139.60
# 3     2010-01-07  1142.00  1159.40  1119.20  1141.00  1144.15
# 4     2010-01-08  1156.00  1172.00  1140.00  1141.20  1144.05
# ...          ...      ...      ...      ...      ...      ...
# 1734  2016-12-26   965.00   965.05   935.00   950.10   950.25
# 1735  2016-12-27   960.70   989.00   952.35   974.00   975.70
# 1736  2016-12-28   980.75   985.00   970.15   977.00   974.40
# 1737  2016-12-29   977.10   997.95   974.55   985.15   986.05
# 1738  2016-12-30   986.00  1006.95   985.90  1004.00  1000.60
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                 101651.0          1157.18
# 1                  59504.0           676.47
# 2                 128908.0          1482.84
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9b3f36af-df14-41cf-9dbd-c4d064caa2f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b3f36af-df14-41cf-9dbd-c4d064caa2f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
glaxo_df = pd.read_csv("GLAXO.csv")
glaxo_df
# Out:
#             Date     Open     High      Low    Last    Close  \
# 0     2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1     2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2     2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3     2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4     2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
# ...          ...      ...      ...      ...     ...      ...
# 1734  2016-12-26  2703.00  2740.00  2677.00  2715.0  2723.50
# 1735  2016-12-27  2722.95  2725.00  2683.00  2692.0  2701.75
# 1736  2016-12-28  2701.75  2718.00  2690.00  2698.0  2702.15
# 1737  2016-12-29  2702.05  2739.00  2691.95  2710.0  2727.90
# 1738  2016-12-30  2730.00  2740.45  2705.00  2730.0  2729.80
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                   9365.0           151.74
# 1                  38148.0           622.58
# 2                  36519.0           595.09
# 3                  12809.0           211.00
# ...

# %%
beml_df[0:11]
# Out:
#           Date    Open     High      Low     Last    Close  \
# 0   2010-01-04  1121.0  1151.00  1121.00  1134.00  1135.60
# 1   2010-01-05  1146.8  1149.00  1128.75  1135.00  1134.60
# 2   2010-01-06  1140.0  1164.25  1130.05  1137.00  1139.60
# 3   2010-01-07  1142.0  1159.40  1119.20  1141.00  1144.15
# 4   2010-01-08  1156.0  1172.00  1140.00  1141.20  1144.05
# 5   2010-01-11  1154.0  1159.45  1134.10  1140.10  1137.00
# 6   2010-01-12  1150.0  1156.90  1117.05  1141.10  1143.65
# 7   2010-01-13  1130.0  1156.80  1125.00  1138.30  1142.25
# 8   2010-01-14  1148.5  1168.50  1145.15  1148.00  1148.20
# 9   2010-01-15  1159.9  1232.00  1151.00  1205.00  1207.05
# 10  2010-01-18  1215.0  1262.30  1197.00  1234.05  1236.25
#
#     Total Trade Quantity  Turnover (Lacs)
# 0               101651.0          1157.18
# 1                59504.0           676.47
# 2               128908.0          1482.84
# 3               117871.0          1352.98
# ...

# %%
glaxo_df[0:11]
# Out:
#           Date     Open     High      Low     Last    Close  \
# 0   2010-01-04  1613.00  1629.10  1602.00  1629.00  1625.65
# 1   2010-01-05  1639.95  1639.95  1611.05  1620.00  1616.80
# 2   2010-01-06  1618.00  1644.00  1617.00  1639.00  1638.50
# 3   2010-01-07  1645.00  1654.00  1636.00  1648.00  1648.70
# 4   2010-01-08  1650.00  1650.00  1626.55  1640.00  1639.80
# 5   2010-01-11  1659.00  1694.95  1601.05  1630.00  1629.45
# 6   2010-01-12  1630.00  1635.00  1578.00  1592.00  1583.85
# 7   2010-01-13  1592.00  1605.90  1566.00  1568.00  1571.30
# 8   2010-01-14  1580.00  1595.00  1562.40  1572.20  1573.55
# 9   2010-01-15  1581.10  1585.00  1565.00  1565.15  1570.40
# 10  2010-01-18  1570.00  1579.90  1556.20  1564.50  1562.50
#
#     Total Trade Quantity  Turnover (Lacs)
# 0                 9365.0           151.74
# 1                38148.0           622.58
# 2                36519.0           595.09
# 3                12809.0           211.00
# ...

# %%
beml_df = beml_df[['Date', 'Close']]
glaxo_df = glaxo_df[['Date', 'Close']]

# %%
beml_df
# Out:
#             Date    Close
# 0     2010-01-04  1135.60
# 1     2010-01-05  1134.60
# 2     2010-01-06  1139.60
# 3     2010-01-07  1144.15
# 4     2010-01-08  1144.05
# ...          ...      ...
# 1734  2016-12-26   950.25
# 1735  2016-12-27   975.70
# 1736  2016-12-28   974.40
# 1737  2016-12-29   986.05
# 1738  2016-12-30  1000.60
#
# [1739 rows x 2 columns]

# %%
glaxo_df
# Out:
#             Date    Close
# 0     2010-01-04  1625.65
# 1     2010-01-05  1616.80
# 2     2010-01-06  1638.50
# 3     2010-01-07  1648.70
# 4     2010-01-08  1639.80
# ...          ...      ...
# 1734  2016-12-26  2723.50
# 1735  2016-12-27  2701.75
# 1736  2016-12-28  2702.15
# 1737  2016-12-29  2727.90
# 1738  2016-12-30  2729.80
#
# [1739 rows x 2 columns]

# %%
'''The DataFrames have a date column, so we can
create a DatetimeIndex index from this column Date. It will ensure that the rows are sorted by time in
ascending order.'''
glaxo_df = glaxo_df.set_index(pd.DatetimeIndex(glaxo_df['Date']))
beml_df = beml_df.set_index(pd.DatetimeIndex(beml_df['Date']))

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
plt.plot(glaxo_df.Close);
plt.xlabel('Time');
plt.ylabel('Close Price');

# %%
plt.plot(beml_df.Close);
plt.xlabel('Time');
plt.ylabel('Close');

# %%
glaxo_df['gain'] = glaxo_df.Close.pct_change(periods = 1)
beml_df['gain'] = beml_df.Close.pct_change(periods = 1)

# %%
#drop first row since it is NaN
glaxo_df = glaxo_df.dropna()
beml_df = beml_df.dropna()

# %%
#Plot the gains
plt.figure(figsize = (8, 6));
plt.plot(glaxo_df.index, glaxo_df.gain);
plt.xlabel('Time');
plt.ylabel('gain');

# %%
sn.distplot(glaxo_df.gain, label = 'Glaxo');
plt.xlabel('gain');
plt.ylabel('Density');
plt.legend();
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sn.distplot(beml_df.gain, label = 'BEML');
plt.xlabel('gain');
plt.ylabel('Density');
plt.legend();
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print('Mean:', round(glaxo_df.gain.mean(), 4))
print('Standard Deviation: ', round(glaxo_df.gain.std(), 4))
# Out:
# Mean: 0.0004
# Standard Deviation:  0.0134

# %%
print('Mean: ', round(beml_df.gain.mean(), 4))
print('Standard Deviation: ', round(beml_df.gain.std(), 4))
# Out:
# Mean:  0.0003
# Standard Deviation:  0.0264

# %%
from scipy import stats
#Probability of making 2% loss or higher in Glaxo
stats.norm.cdf( -0.02,
loc=glaxo_df.gain.mean(),
scale=glaxo_df.gain.std())
# Out:
# 0.06352488667177401

# %%
#Probability of making 2% gain or higher in Glaxo
1 - stats.norm.cdf(0.02,
loc=glaxo_df.gain.mean(),
scale=glaxo_df.gain.std())
# Out:
# 0.07104511457618568

# %% [markdown]
# ### Inclass Exercise

# %% [markdown]
# ### Compute 2% loss or gain for BEML

# %%
stats.norm.cdf( -0.02,
loc=beml_df.gain.mean(),
scale=beml_df.gain.std())
# Out:
# 0.22155987503755298

# %%
#Probability of making 2% gain or higher in BEML
1 - stats.norm.cdf(0.02,
loc=beml_df.gain.mean(),
scale=beml_df.gain.std())
# Out:
# 0.22769829484075343
